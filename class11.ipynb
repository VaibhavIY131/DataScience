# %%
# List:
# A list in python is a collection of items stored in a single variable.
# Lists are ordered,changable.and allow duplicates.
# Lists are defined using square brackets []






# fruits = ["vaibhav","sahil","raj","vidhush"]
# fruits.extend(["shiv","ram"])
# print(fruits)


# fruits = ["vaibhav","sahil","raj","vidhush"]
# print(fruits)
# print(fruits[1])
# print(fruits[3])



# fruits = ["vaibhav","sahil","raj","vidhush"]
# fruits.append("shiv")
# print(fruits)



# fruits = ["vaibhav","sahil","raj","vidhush"]
# fruits.insert(2,"shiv")
# print(fruits)
# fruits.remove("raj")
# print(fruits)
# fruits.clear()
# print(fruits)

    





# names = ["vaibhav","sahil","raj","vidhush"]
# count = names.count("raj")
# print (count)


# num = [1,5,2,9,3,6,]
# num.sort()
# print(num)
# num.reverse()
# print(num)



# names = ["vaibhav","sahil","raj","vidhush"]
# num = [1,5,2,9,3,6,]
# add = num + names
# print(add)




# num = [1,5,2,9,3,6,]
# list = num*2
# print(list)


 
# names =  ["vaibhav","sahil","raj","vidhush"]
# print(len(names))
 
 
# names = [["vaibhav","sahil","raj","vidhush"], ["shiv","ram"]]
# print(names[0][1])
# print(names[1][0])
# print(names[0][3])





# Write a program to check if the list my_list = [] is empty or not.

 
# def list1():
#     names =  ["vaibhav","sahil","raj","vidhush"]
#     if names == []:
#         print("list is empty")
#     else:
#         print("list is not empty")
# list1()
    
 
 
#  Write a program to find the sum of all numbers in the list numbers = [1, 2, 3, 4, 5].


# number = [1,2,3,4,5]

# total = sum(number)
# print(total)    

# def sum1(numbers):
#     total = 0
#     for num in numbers:
#         total += num
#     return total
# numbers = [1,2,3,4,5]
# print(sum1(numbers))

    
# def square():
#     squares = []
#     for num in range(1,11):
#         squares.append(num**2)
#     return squares 
# print(square())

Write a program to create a list of squares of numbers from 1 to 10.

Write a program to find the index of the maximum value in the list numbers = [10, 20, 30, 25, 5]
Write a program to find the index of the minimum\ value in the list numbers = [10, 20, 30, 25, 5]
even and odd progaram through list
