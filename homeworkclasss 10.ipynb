# %%
# def calculate1(a,b):
#     if (a>b):
#         print("first number is greater")
#     else:
#         print("second number is greater or equal")

# def calculate2(a,b):
#     if (a*b)== 10:
#         print("answer is correct")
#     else:
#         print("answer is wrong")
# def calculate3(a,b):
#     multiplication = (a*b)
#     print(multiplication)
    
    
# a= 5
# b=2
# calculate1(a,b)
# calculate2(a,b)
# calculate3(a,b)

# c=1
# d=5
# calculate1(c,d)
# calculate2(c,b)
# calculate3(c,d)




# def calculate_total_salary(overtime_pay,base_salary,hourly_rate):
    
#     return base_salary+(hourly_rate*1.5*overtime_work)
# overtime_work = float(input("how many hours of work: "))
# base_salary = float(input("what is the base salary: "))
# hourly_rate = float(input("what is the hourly rate: "))

# result =  calculate_total_salary(base_salary,overtime_work,hourly_rate)

# print(result)

    
    
    
# Write a function that calculates the perimeter of a rectangle given its length and width.
    
# def perimeter(l,w):
#     return 2*(l+w)
# l = 10
# w = 12

# print(perimeter(l,w))


# Write a function that takes the radius of a circle and returns the area.

# def raduis(r):
#     return 3.14*r**2
# r = 5
# print(raduis(r))
# 1 Create a Python program to compare three numbers and print whether they are all equal, any two are equal, or all are different using only comparison operators.

# def num1(a,b,c):
#     if (a == b) and (b == c):
#         print("all equal")
#     elif (a == b) or (b == c) or (a == c):
#         print("any two equal")
#     elif (a != b) and (b != c) and (a != c):
#         print("all different")
# a = int(input("Enter the first number: "))
# b = int(input("Enter the second number: "))
# c = int(input("Enter the third number: "))
# num1(a,b,c)

    

# 2 Write a Python program that checks if a number is even, odd, or zero. The program should:

# Print "Even" if the number is divisible by 2.
# Print "Odd" if the number is not divisible by 2.
# Print "Zero" if the number is equal to 0.


# def num1():
#     if n ==0:
#         print("zero")
#     elif n%2==0:
#         print("even")
#     else:
#         print("odd")
# n = int(input("Enter the number: "))
# num1()
    
 


# 3  Calculate Discount Based on Purchase Amount: Write a Python program that calculates a discount based on the purchase amount. The program should:

# Print "20% discount" if the amount is greater than 100.
# Print "10% discount" if the amount is between 50 and 100.
# Print "No discount" if the amount is less than 50.

# def amount1(amount):
#     if amount>100:
#         print("20% discount")
#     elif amount>=50:
#         print("10% discount")
#     else:
#         print("No discount")
# amount = int(input("Enter the Amount: "))
# amount1(amount)
        





# 4 Write a Python program that identifies the time of day based on the hour. The program should:

# Print "Morning" if the hour is between 6 and 11 (inclusive).
# Print "Afternoon" if the hour is between 12 and 17 (inclusive).
# Print "Evening" if the hour is between 18 and 23 (inclusive).
# Print "Invalid hour" if the hour is not between 0 and 23.


# def hour1():
#     if 6< hour <11:
#         print("Morning")
#     elif 12< hour <17:
#         print("Afternoon")
#     elif 18< hour <23:
#         print("Evening")
#     else:
#         print("Invalid hour")
# hour = int(input("Enter the the hour: "))
# hour1()
    




# 5 Write a Python program to calculate the sum of all even numbers from 1 to 100 using a loop.



# def sum_of_even_numbers(start, end):
#     even_sum = 0
    
#     for num in range(start, end + 1):
#         if num % 2 == 0:
#             even_sum += num  
    
#     return even_sum

# result = sum_of_even_numbers(1, 100)
# print("The sum of all even numbers from 1 to 100 is:", result)





# 6  Write a Python program to count the number of vowels in a given string using a loop.


# def count_vowels(input_string):
#     vowels = "aeiouAEIOU"
#     count = 0
    
#     for char in input_string:
#         if char in vowels:
#             count += 1 
            
#     return count

# user_input = input("Enter a string: ")
# vowel_count = count_vowels(user_input)
# print("The number of vowels in the given string is:", vowel_count)





# 7  Write a program to print numbers from 1 to 15, skipping numbers that are divisible by 3.

# def num_divisible_by_3():
#     for num in range(1, 16):
#         if num % 3 == 0:
#             continue  
#         print(num)  
# num_divisible_by_3()







# 8  Write a program that processes a string and prints each character, skipping the character 'a' 



# def process_string(input_string):
#     for char in input_string:
#         if char == 'd':
#             break
#         if char == 'a':
#             continue
#         print(char)

# user_input = input("Enter a string: ")
# process_string(user_input)
