# %%
#Break statement:The break statement is used to exit or terminate a loop
# immediately.When the break statement is executed , the loop stops
# and the program continues with the next statement after the loop.

# for number in range(1,6):
#     print(number)
#     if number == 3:
#         break
# print("Loop end")


# for num in range(1,11):
#     if num%2 == 0:
#         break
#     print(num)

# 2.Continue:skip the rest of the code inside the loop for the current iteration
# and continue with

for number in range(1,6):
#     if number ==3:
#         continue
#     print(number)



# number = 1
# while number <=20:
#     if number%4!=0:
#         number +=1
#         continue
#     print(number)
#     number +=1


# for i in range(1,6):
#     for j in range(1,6):
#         print(i*j,end = " ")
#     print()
    
    
    # *
    # * *
    # * * *
    # * * * *
    # * * * * *


# rows = 5
# for i in range(1,rows+1):
#     for j in range(i):
#         print("*",end = " ")
#     print()
the next iteration. 
#Write a Python program to count the number of vowels in a given string using a loop.

# s = input("Enter a string: ")

# count = 0

# for i in s:

#     if i in 'aeiou':
#         count += 1

# print("Number of vowels: ",count)

# for number in range (1,6):
#     print(number)
#     if number  ==3:
#       break
# print("loop ends")


# for number in range (1,11):
#     if number %2 !=0:
#         continue
#     print(number)

# rows = 8
# for i in range (1,rows+1):
#     for j in range (i):
#         print("*",end = "    ")
#     print()


# for i in range (1,6):
#     for j in range (1,6):
#         print(i*j,end= " ")
#     print()
        


# for i in range(1, 11):
#     for j in range(1, 11):
#         print("{:2}".format(i * j), end=" ")
#     print()

   
# for i in range(1, 11):
#     for j in range(1, 11):
#         print(f"{i * j:2}", end=" ")
#     print() 

    
# Write a program to print numbers from 1 to 15, skipping numbers that are divisible by 3.



# for i in range (1,16):
#     if i %3 ==0:
#         continue
#     print(i)


# Write a program to sum numbers from 1 until the total exceeds 20. Print the sum and stop the loop when the condition is met.


# total_sum =0
# for number in range (1,100):
#     total_sum += number
#     if total_sum>20:
#         break
# print(total_sum)


# Write a program that prints numbers from 1 to 10, skipping the number 5 and stopping when it prints the number 8.

# for i in range (1,10):
#     if i == 5:
#         continue
#     if i == 8:
#         print(i)
#         break
#     print(i)
Write a program that prints numbers from 1 to 15, skipping odd numbers and stopping when it reaches the number 12
Write a program that processes a string and prints each character, skipping the character 'a' and stopping when it encounters the character 'd'

# Write a program that prints numbers from 1 to 15, skipping odd numbers and stopping when it reaches the number 12

# for num in range(1, 16):  
#     if num % 2 == 0:    
#         print(num)       
#         if num == 12:
#             break




# Write a program that processes a string and prints each character, skipping the character 'a' and stopping when it encounters the character 'd'
    
    
    

# input_string = str(input("Enter string: "))

# for i in input_string:
#     if i == 'd': 
#         break
#     if i != 'a':  
#         print(i)
