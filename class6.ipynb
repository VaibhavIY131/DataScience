# %%
# Loops:
# 1.while loops
# 2.For loops:
# while loop:it allowss a block of code to excute repeatedly as long as specified
# condition is true.
# condition evaluation:
# execution:
# Termination:

# number = 1
# while number <5:
#     print(number)
#     number +=2



# n = 5
# while n>0:
#     print(n)
#     n -=1
# else:
#     print("Loop completed")
# 2. for loops:

# for variable in sequence:

# for num in range(1,6):
#     print(num)

# fruits = ["apple","banana","orange"]
# for fruit in fruits:
#     print(fruit)


# for number in range(1,101):
#     print(number)

# number = 1
# while number <=100:
#     print(number)
#     number +=2

# total = 0
# for number in range(1, 21):
#     total += number
# print("Sum:", total)
# for i in range(1, 11):
#     print( 2 * i)

 Emma is planning a trip and wants to determine the mode of transportation based on the distance of the destination. Write a Python program to help Emma where she can input the distance in kilometers, and the program will suggest the mode of transportation. If the distance is less than 100 kilometers, suggest using a bicycle. If the distance is between 100 and 500 kilometers, suggest using a train. If the distance is greater than 500 kilometers, suggest using a flight.


# distance = float(input("Enter the distance in km: "))

# if distance<100:
#     print("use a bicycle")
# elif 100<= distance <=500:
#     print("use train")
# else:
#     print("use flight")


# n = 1
# while n<10:
#     print(n)
#     n +=1

# n = 10
# while n<100:
#     print(n)
#     n +=1


# names = ("vaibhav", "sahil" , "shubh")
# for name in names:
#     print(name)



# for number in range (1,12):
#     print(number)

# for number in range (10,31,2):
#     print(number)


# Write a Python program that calculates and prints the sum of numbers from 1 to 20.

# total = 0
# for number in range (1,21):
#     total +=number
# print(total)

# Write a Python program that prints all numbers between 50 and 70 that are divisible by 4


# for number in range (50,71):
#     if number%4==0:
#         print(number)

# for number in range (3,31):
#     if number%3==0:
#         print(number)


# for number in range (1,11):
#     print(5*number)



Write a Python program to print the squares of the first 10 natural numbers.
Write a Python program to generate and print the Fibonacci sequence up to 50.
Write a Python program that counts down from a number entered by the user to 0, printing each number.
Write a Python program to print all prime numbers between 1 and 30.
