# %%
#price = float (input("Enter the price"))
#print(price)

#age= int(input("Enter ur age"))
#print(age)
#name= input("enter the names").split()
#print(name)

#x,y,z= input("enter the numbers").split()
#print(x,y,z)

#name= input("enter ur name")
#print(name)

#Write a Python program that asks the user for two integers and prints their sum.

#addition1=int(input("enter the first number"))
#addition2= int(input("enter the second number"))
#print(addition1+addition2)

#Write a Python program that takes three names as input on a single line and prints them.

#name1,name2,name3=input("enter the three names").split()
#print(name3,name2,name1)

#Write a Python program that takes temperature in Fahrenheit as input and converts it to Celsius.
#celsius = (fahrenheit - 32) * 5/9

#fahrenheit= float (input("temperature in fahrenheit"))
#celsius = (fahrenheit - 32) * 5/9
#print(celsius)


#Emma runs a small bakery and wants to create a program to calculate the total revenue for the day. Write a program that asks the user to enter the number of each type of pastry sold (croissants, muffins, and cookies) and then calculates and prints the total revenue for the day. 
#Assume the prices of each item are as follows:  
#Croissant: $2.50 
#Muffin: $2.00 
#Cookie: $1.50

#pastry1= int (input("enter the numnber of Croisssant sold"))
#pastry2= int (input("enter the number of Muffin sold"))
#pastry3= int (input("enter the number of Cookie sold"))

#revenue1=  (pastry1*2.50)
#revenue2=  (pastry2*2.00)
#revenue3=  (pastry3*1.50)
#total_revenue= revenue1+revenue2+revenue3

#print(total_revenue)


#Numerical data types;
#my_integer = 42
#my_float = 4.3

#String:
#My_name = "Alice"
#paragaph = "Hey i am here."


#boolean data type:
#Is_raining = True
#is_sunny = False
