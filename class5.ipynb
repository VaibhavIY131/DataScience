# %%
# Conditional operators:
# if ,elif,else

# if statement:The if statement is used to execute a block of code only if  a specific condition is True.

# if condition:
#     #code will execture if condition is true.

# x = 7
# if x > 5:
#     print("x is greater than 5")
    
    
# name = "Raman"
# if name == "Raman":
#     print("Hey How are u?")

# number = 5
# if number%2!=0:
#     print("The number is odd")


# age = 39
# if age >=39:
#     print("Eligble")


# a, b =5 ,10
# if a<b and a>0:
#
a, b =5 ,10
# if a<b and a>0:
#     print("a is positive and less than b")

# user_input = int(input("enter a number:"))
# if user_input >5:
#     print("it is greater")



# 2.elif statement:

# number = int(input("enter the number"))
# if number>0:
#     print("positive")
# elif number <0:
#     print("negative")


# score = 85
# if score>=90:
#     print("A")
# elif score >=80:
#     print("B")
# elif score >=70:
#     print("C")

# text = ""
# if text:
#     print("string is not empty")
# e
else:
#     print("string is empty")


# light = "red" 
# if light == "red":
#     print("stop")
# elif light=="green":
#     print("go")
# else:
#     print("invalid light")


# Create a Python program to compare three numbers and print whether they are all equal, any two are equal, or all are different using only comparison operators.

# a = int(input("Enter the first number: "))
# b = int(input("Enter the second number: "))
# c = int(input("Enter the third number: "))

# all_equal = (a == b) and (b == c)
# any_two_equal = (a == b) or (b == c) or (a == c)
# all_different = (a != b) and (b != c) and (a != c)

# print(all_equal)
# print(any_two_equal)
# print(all_different)

# x = 8
# if x>5:
#     print("x is greater then 5")

# age = 25

# if age >20:
#     print("ur elligible")

# a,b = 5, 10
# if a<b and a>0:
#     print("a is suitable")

# num_1 = int(input("enter the number: "))
# if num_1>30:
#     print("the number is greater then 30")


# num = int(input("enter the number: "))
# if num %2 ==0:
#     print("the number is even")

# num_1 = int(input("enter the number: "))
# if num_1>20:
#     print("if won")
# elif num_1<20:
#     print("elif won")


# Write a Python program that checks if a number is even, odd, or zero. The program should:

# Print "Even" if the number is divisible by 2.
# Print "Odd" if the number is not divisible by 2.
# Print "Zero" if the number is equal to 0.



# num_1 = int(input("Enter the numeber: "))

# if num_1==0:
#     print("zero")
# elif num_1%2==0:
#     print("even")
# else:
#     print("odd")
    
    
# Calculate Discount Based on Purchase Amount: Write a Python program that calculates a discount based on the purchase amount. The program should:

# Print "20% discount" if the amount is greater than 100.
# Print "10% discount" if the amount is between 50 and 100.
# Print "No discount" if the amount is less than 50.


# amount = int(input("Enter the Amount: "))
# if amount>100:
#     print("20% discount")
    
# elif amount>=50:
#     print("10% discount")
# else:
#     print("No discount")


# Write a Python program that provides advice based on the temperature in Celsius. The program should:

# Print "It's hot" if the temperature is above 30°C.
# Print "It's warm" if the temperature is between 15°C and 30°C.
# Print "It's cold" if the temperature is below 15°C

# temperature = float(input("Enter the temperature in Celsius: "))

# if temperature>30:
#     print("it's is hot!")
# elif 15< temperature <=30:
#     print("it's warm")
# else:
#     print("its cold")





# Write a Python program that checks if a person is eligible for a senior citizen discount. The program should:

# Print "Eligible for discount" if the age is 65 or older.
# Print "Not eligible for discount" if the age is less than 65.


# age = int(input("Enter the age: "))

# if age>=65:
#     print("Eligible for discount")
# else:
#     print("Not eligible for discount")







# Write a Python program that identifies the time of day based on the hour. The program should:

# Print "Morning" if the hour is between 6 and 11 (inclusive).
# Print "Afternoon" if the hour is between 12 and 17 (inclusive).
# Print "Evening" if the hour is between 18 and 23 (inclusive).
# Print "Invalid hour" if the hour is not between 0 and 23.

# hour = int(input("Enter the the hour: "))

# if 6< hour <11:
#     print("Morning")
# elif 12< hour <17:
#     print("Afternoon")
# elif 18< hour <23:
#     print("Evening")
# else:
#     print("Invalid hour")
