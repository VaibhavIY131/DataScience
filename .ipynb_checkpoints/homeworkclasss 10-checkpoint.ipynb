# %%
# def calculate1(a,b):
#     if (a>b):
#         print("first number is greater")
#     else:
#         print("second number is greater or equal")

# def calculate2(a,b):
#     if (a*b)== 10:
#         print("answer is correct")
#     else:
#         print("answer is wrong")
# def calculate3(a,b):
#     multiplication = (a*b)
#     print(multiplication)
    
    
# a= 5
# b=2
# calculate1(a,b)
# calculate2(a,b)
# calculate3(a,b)

# c=1
# d=5
# calculate1(c,d)
# calculate2(c,b)
# calculate3(c,d)




# def calculate_total_salary(overtime_pay,base_salary,hourly_rate):
    
#     return base_salary+(hourly_rate*1.5*overtime_work)
# overtime_work = float(input("how many hours of work: "))
# base_salary = float(input("what is the base salary: "))
# hourly_rate = float(input("what is the hourly rate: "))

# result =  calculate_total_salary(base_salary,overtime_work,hourly_rate)

# print(result)

    
    
    
# Write a function that calculates the perimeter of a rectangle given its length and width.
    
# def perimeter(l,w):
#     return 2*(l+w)
# l = 10
# w = 12

# print(perimeter(l,w))


# Write a function that takes the radius of a circle and returns the area.

# def raduis(r):
#     return 3.14*r**2
# r = 5
# print(raduis(r))


# Write a function that accepts a number and returns True if the number is divisible by 5, otherwise False.


# def number(number2):
    
#     if number2%5==0:
#         print("the number is true")
#     else:
#         print("the number is false")
        
# number2 = int(input("enter the number"))
        
    
# number(number2)
    
    


# def devision(n):
#     return n%5==0
# num = int(input("enter the number: "))
# print(devision(num))

 
 
 
# def square():
    
#     return n**2
# n = 5
# print(square())
