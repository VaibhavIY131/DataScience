# %%
# Q1. Write a Python program to demonstrate multiple inheritance.
# 1. Employee class has 3 data members EmployeeID, Gender (String), Salary and
# PerformanceRating(Out of 5) of type int. It has a get() function to get these details from
# the user.

from datetime import datetime

class Employee:
    def __init__(self):
        self.EmployeeID = None
        self.Gender = None
        self.Salary = None
        self.PerformanceRating = None

    def get_details(self):
        self.EmployeeID = input("Enter Employee ID: ")
        self.Gender = input("Enter Gender: ")
        self.Salary = float(input("Enter Salary: "))
        self.PerformanceRating = int(input("Enter Performance Rating (1-5): "))
        
        while self.PerformanceRating < 1 or self.PerformanceRating > 5:
            print("Performance Rating must be between 1 and 5.")
            self.PerformanceRating = int(input("Enter Performance Rating (1-5): "))


class JoiningDetail:
    def __init__(self):
        self.DateOfJoining = None

    def get_DoJ(self):
        doj_input = input("Enter Date of Joining (YYYY-MM-DD): ")
        self.DateOfJoining = datetime.strptime(doj_input, "%Y-%m-%d").date()


class Information(Employee, JoiningDetail):
    def __init__(self):
        Employee.__init__(self)
        JoiningDetail.__init__(self)

    def read_data(self):
        self.get_details()
        self.get_DoJ()

    @staticmethod
    def calculate_top_employees(employees):
        sorted_employees = sorted(employees, key=lambda x: (-x.PerformanceRating, x.DateOfJoining))
        
        return sorted_employees[:3]

    @staticmethod
    def display_employees(employees):
        print("\nTop Employees Based on Performance Rating:")
        for emp in employees:
            print(f"Employee ID: {emp.EmployeeID}, Gender: {emp.Gender}, Salary: ${emp.Salary:.2f}, "
                  f"Performance Rating: {emp.PerformanceRating}/5, Date of Joining: {emp.DateOfJoining}")


if __name__ == "__main__":
    employee_list = []
    
    for _ in range(5):
        emp_info = Information()
        emp_info.read_data()
        employee_list.append(emp_info)

    top_employees = Information.calculate_top_employees(employee_list)

    Information.display_employees(top_employees)

# %%
# Q.2 Write a Python program to demonstrate Polymorphism.
# 1. Class Vehicle with a parameterized function Fare, that takes input value as fare and
# returns it to calling Objects.
# 2. Create five separate variables Bus, Car, Train, Truck and Ship that call the Fare
# function.
# 3. Use a third variable TotalFare to store the sum of fare for each Vehicle Type. 4. Print the TotalFare.


class Vehicle:
    def fare(self, fare):
        return fare

class Bus(Vehicle):
    def fare(self, fare):
        return fare * 

class Car(Vehicle):
    def fare(self, fare):
        return fare * 

class Train(Vehicle):
    def fare(self, fare):
        return fare * 1.2  

class Truck(Vehicle):
    def fare(self, fare):
        return fare * 2.5  

class Ship(Vehicle):
    def fare(self, fare):
        return fare * 3.0  

# Main program
if __name__ == "__main__":
    base_fare = 100  
    total_fare = 0

    
    bus = Bus()
    car = Car()
    train = Train()
    truck = Truck()
    ship = Ship()

   
    total_fare += bus.fare(base_fare)
    total_fare += car.fare(base_fare)
    total_fare += train.fare(base_fare)
    total_fare += truck.fare(base_fare)
    total_fare += ship.fare(base_fare)

    print(f"Total Fare for all Vehicles: ${total_fare:.2f}")

# %%
# Q3. Consider an ongoing test cricket series. Following are the names of the players and their scores in the test1 and 2.
# Test Match 1 :
# Dhoni : 56 , Balaji : 94
# Test Match 2 :
# Balaji : 80 , Dravid : 105
# Calculate the highest number of runs scored by an individual cricketer in both of the matches. Create a python function Max_Score (M) that reads a dictionary M that recognizes the player with the highest total score. This function will return ( Top player , Total Score ) . You can consider the Top player as String who is the highest scorer and Top score as Integer .
# Input : Max_Score({‘test1’:{‘Dhoni’:56, ‘Balaji : 85}, ‘test2’:{‘Dhoni’ 87, ‘Balaji’’:200}}) Output : (‘Balaji ‘ , 200)


def max_score(matches):

    total_scores = {}

    for match, players in matches.items():
        for player, score in players.items():
            if player in total_scores:
                total_scores[player] += score
            else:
                total_scores[player] = score

    if total_scores:
        top_player = max(total_scores, key=total_scores.get)
        top_score = total_scores[top_player]
        return top_player, top_score
    else:
        return None, 0  

def main():
    matches = {
        'test1': {'Dhoni': 56, 'Balaji': 94},
        'test2': {'Balaji': 80, 'Dravid': 105}
    }
    
    top_player, top_score = max_score(matches)
    
    if top_player:
        print(f"The top player is '{top_player}' with a total score of {top_score}.")
    else:
        print("No players found.")

if __name__ == "__main__":
    main()

# %%
# Q4. Create a simple Card game in which there are 8 cards which are randomly chosen from a deck. The first card is shown face up. The game asks the player to predict whether the next card in the selection will have a higher or lower value than the currently showing card.
# For example, say the card that’s shown is a 3. The player chooses “higher,” and the next card is shown. If that card has a higher value, the player is correct. In this example, if the player had chosen “lower,” they would have been incorrect. If the player guesses correctly, they get 20 points. If they choose incorrectly, they lose 15 points. If the next card to be turned over has the same value as the previous card, the player is incorrect.


import random

def create_deck():
    values = list(range(1, 14))  
    deck = values * 4 
    random.shuffle(deck)  
    return deck

def play_game():
    deck = create_deck()  
    score = 0
    current_card = deck.pop() 
    print(f"Current card: {current_card}")

    for _ in range(7):  
        guess = input("Will the next card be higher or lower? (h/l): ").strip().lower()
        next_card = deck.pop()  # Get the next card
        print(f"Next card: {next_card}")

        if (next_card > current_card and guess == 'h') or (next_card < current_card and guess == 'l'):
            score += 20
            print("Correct! You've earned 20 points.")
        else:
            score -= 15
            print("Incorrect! You've lost 15 points.")

        if next_card == current_card:
            score -= 15
            print("The same value! You've lost 15 points.")

        current_card = next_card  
        print(f"Current score: {score}\n")

    print(f"Game over! Your final score is: {score}")

if __name__ == "__main__":
     play_game()

# %%
# Q5. Create an empty dictionary called Car_0 . Then fill the dictionary with Keys : color , speed , X_position and Y_position.
# car_0 = {'x_position': 10, 'y_position': 72, 'speed': 'medium'} .
# a) If the speed is slow the coordinates of the X_pos get incremented by 2.
# b) If the speed is Medium the coordinates of the X_pos gets incremented by 9
# c) Now if the speed is Fast the coordinates of the X_pos gets incremented by 22.
# Print the modified dictionary.


def create_car(color, speed, x_position, y_position):
    """Create a car dictionary."""
    return {
        'color': color,
        'x_position': x_position,
        'y_position': y_position,
        'speed': speed
    }

def update_x_position(car):
    """Update the x_position of the car based on its speed."""
    speed = car['speed'].lower()  

    if speed == 'slow':
        car['x_position'] += 2
    elif speed == 'medium':
        car['x_position'] += 9
    elif speed == 'fast':
        car['x_position'] += 22
    else:
        print("Invalid speed value. No update made.")

def print_car_state(car):
    """Print the current state of the car."""
    print("Current car state:")
    for key, value in car.items():
        print(f"{key.capitalize()}: {value}")

# Main program
if __name__ == "__main__":
    color = input("Enter the color of the car: ")
    speed = input("Enter the speed of the car (slow/medium/fast): ")
    
    x_position = 10
    y_position = 72

    car_0 = create_car(color, speed, x_position, y_position)

    print_car_state(car_0)

    update_x_position(car_0)

    print_car_state(car_0)

# %%
# Q6. Show a basic implementation of abstraction in python using the abstract classes. 1. Create an abstract class in python.
# 2. Implement abstraction with the other classes and base class as abstract class.

from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    
    @abstractmethod
    def area(self):
        pass  

    @abstractmethod
    def perimeter(self):
        pass  

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.radius

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)


def main():
    circle = Circle(5)
    print(f"Circle: Area = {circle.area()}, Perimeter = {circle.perimeter()}")

    rectangle = Rectangle(4, 6)
    print(f"Rectangle: Area = {rectangle.area()}, Perimeter = {rectangle.perimeter()}")

if __name__ == "__main__":
    main()

# %%
# Q7. Create a program in python to demonstrate Polymorphism.
# 1. Make use of private and protected members using python name mangling techniques.

class Shape:
    def __init__(self):
        self._protected_value = 10  

    def area(self):
        raise NotImplementedError("Subclasses must implement this method.")

    def _protected_method(self):
        return f"Protected value is {self._protected_value}"

class Circle(Shape):
    def __init__(self, radius):
        super().__init__() 
        self.__radius = radius  

    def area(self):
        return 3.14 * (self.__radius ** 2)

    def get_radius(self):
        return self.__radius

    def show_protected_value(self):
        return self._protected_method()

def main():
    circle = Circle(5)
    
    print(f"Area of the circle: {circle.area()}")
    print(f"Radius of the circle: {circle.get_radius()}")
    print(circle.show_protected_value())

    try:
        print(circle.__radius)  
    except AttributeError as e:
        print(f"Error: {e}")

    print(f"Accessing private member using name mangling: {circle._Circle__radius}")

if __name__ == "__main__":
    main()

# %%
# Q8. Given a list of 50 natural numbers from 1-50. Create a function that will take every element from the list and return the square of each element. Use the python map and filter methods to implement the function on the given list.
# List of natural numbers from 1 to 50


numbers = list(range(1, 51))

def square(num):
    return num ** 2

squared_numbers = list(map(square, numbers))


even_squared_numbers = list(filter(lambda x: x % 2 == 0, squared_numbers))

# Output the results
print("Squared Numbers:", squared_numbers)
print("Even Squared Numbers:", even_squared_numbers)

# %%
# Q9. Create a class, Triangle. Its init() method should take self, angle1, angle2, and angle3 as arguments.


class Triangle:
    def __init__(self, angle1, angle2, angle3):
        self.angle1 = angle1
        self.angle2 = angle2
        self.angle3 = angle3

    def is_valid(self):
        return (self.angle1 + self.angle2 + self.angle3 == 180) and \
               all(angle > 0 for angle in [self.angle1, self.angle2, self.angle3])

    def triangle_type(self):
        if not self.is_valid():
            return 
        
        if self.angle1 < 90 and self.angle2 < 90 and self.angle3 < 90:
            return 
        elif self.angle1 == 90 or self.angle2 == 90 or self.angle3 == 90:
            return 
        else:
            return 

# Example usage
if __name__ == "__main__":
    # Create a Triangle instance
    triangle = Triangle(60, 70, 50)

    # Check if the triangle is valid and determine its type
    if triangle.is_valid():
        print(f"The triangle with angles {triangle.angle1}, {triangle.angle2}, and {triangle.angle3} is valid.")
        print("Type of triangle:", triangle.triangle_type())
    else:
        print("The triangle is not valid.")

# %%
# Q10. Create a class variable named number_of_sides and set it equal to 3.

class Polygon:
    number_of_sides = 3  

    def __init__(self, name):
        self.name = name

    def display_info(self):
        print(f"A {self.name} has {Polygon.number_of_sides} sides.")


if __name__ == "__main__":
    polygon = Polygon("Triangle")

    polygon.display_info()

    print(f"Number of sides in a polygon: {Polygon.number_of_sides}")

# %%
# Q11. Create a method named check_angles. The sum of a triangle's three angles should return True if the sum is equal to 180, and False otherwise. The method should print whether the angles belong to a triangle or not.
# 11.1 Write methods to verify if the triangle is an acute triangle or obtuse triangle.
# 11.2 Create an instance of the triangle class and call all the defined methods.
# 11.3 Create three child classes of triangle class - isosceles_triangle, right_triangle and equilateral_triangle.
# 11.4 Define methods which check for their properties.

class Triangle:
    def __init__(self, angle1, angle2, angle3):
        self.angle1 = angle1
        self.angle2 = angle2
        self.angle3 = angle3

    def check_angles(self):
        """Check if the sum of the angles equals 180 degrees."""
        total = self.angle1 + self.angle2 + self.angle3
        if total == 180:
            print("The angles belong to a triangle.")
            return True
        else:
            print("The angles do not belong to a triangle.")
            return False

    def is_acute(self):
        """Check if the triangle is an acute triangle."""
        if self.check_angles():
            return all(angle < 90 for angle in [self.angle1, self.angle2, self.angle3])
        return False

    def is_obtuse(self):
        """Check if the triangle is an obtuse triangle."""
        if self.check_angles():
            return any(angle > 90 for angle in [self.angle1, self.angle2, self.angle3])
        return False


class IsoscelesTriangle(Triangle):
    def check_isosceles(self):
        """Check if the triangle is isosceles."""
        return (self.angle1 == self.angle2 or
                self.angle1 == self.angle3 or
                self.angle2 == self.angle3)


class RightTriangle(Triangle):
    def check_right(self):
        """Check if the triangle is a right triangle."""
        return 90 in [self.angle1, self.angle2, self.angle3]


class EquilateralTriangle(Triangle):
    def check_equilateral(self):
        """Check if the triangle is equilateral."""
        return self.angle1 == self.angle2 == self.angle3 == 60


# Example usage
if __name__ == "__main__":
    triangle = Triangle(60, 70, 50)

    print("Angles:", triangle.angle1, triangle.angle2, triangle.angle3)
    triangle.check_angles()
    print("Is acute triangle:", triangle.is_acute())
    print("Is obtuse triangle:", triangle.is_obtuse())

    isosceles = IsoscelesTriangle(70, 70, 40)
    right = RightTriangle(90, 45, 45)
    equilateral = EquilateralTriangle(60, 60, 60)

    print("\nIsosceles Triangle:")
    print("Is valid triangle:", isosceles.check_angles())
    print("Is isosceles:", isosceles.check_isosceles())

    print("\nRight Triangle:")
    print("Is valid triangle:", right.check_angles())
    print("Is right:", right.check_right())

    print("\nEquilateral Triangle:")
    print("Is valid triangle:", equilateral.check_angles())
    print("Is equilateral:", equilateral.check_equilateral())

# %%
# Q12. Create a class isosceles_right_triangle which inherits from isosceles_triangle and right_triangle.
# 12.1 Define methods which check for their properties.

class Triangle:
    def __init__(self, angle1, angle2, angle3):
        self.angle1 = angle1
        self.angle2 = angle2
        self.angle3 = angle3

    def check_angles(self):
        """Check if the sum of the angles equals 180 degrees."""
        total = self.angle1 + self.angle2 + self.angle3
        if total == 180:
            print("The angles belong to a triangle.")
            return True
        else:
            print("The angles do not belong to a triangle.")
            return False

    def is_acute(self):
        """Check if the triangle is an acute triangle."""
        if self.check_angles():
            return all(angle < 90 for angle in [self.angle1, self.angle2, self.angle3])
        return False

    def is_obtuse(self):
        """Check if the triangle is an obtuse triangle."""
        if self.check_angles():
            return any(angle > 90 for angle in [self.angle1, self.angle2, self.angle3])
        return False


class IsoscelesTriangle(Triangle):
    def check_isosceles(self):
        """Check if the triangle is isosceles."""
        return (self.angle1 == self.angle2 or
                self.angle1 == self.angle3 or
                self.angle2 == self.angle3)


class RightTriangle(Triangle):
    def check_right(self):
        """Check if the triangle is a right triangle."""
        return 90 in [self.angle1, self.angle2, self.angle3]


class IsoscelesRightTriangle(IsoscelesTriangle, RightTriangle):
    def check_isosceles_right(self):
        """Check if the triangle is both isosceles and right."""
        return self.check_isosceles() and self.check_right()


if __name__ == "__main__":
    isosceles_right_triangle = IsoscelesRightTriangle(45, 45, 90)

    # Call the defined methods
    print("Angles:", isosceles_right_triangle.angle1, isosceles_right_triangle.angle2, isosceles_right_triangle.angle3)
    print("Is valid triangle:", isosceles_right_triangle.check_angles())
    print("Is isosceles:", isosceles_right_triangle.check_isosceles())
    print("Is right:", isosceles_right_triangle.check_right())
    print("Is isosceles right:", isosceles_right_triangle.check_isosceles_right())
