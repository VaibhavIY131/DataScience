# %%
#type casting:

#x = int(10)
#print (type(x))

#x = 20
#y= float(x)
#print(y)
#print(type(y))

#x = 3.5
#y= int(x)
#print(y)
#print(type(y))

#x = "54"
#y = int(x)
#print(y)
#print(type(y))

# x="23"
# y=float(x)
# print(y)
# print(type(y))

# x =50
# y =str(x)
# print(y)
# print(type(y))

# x = 23.4
# y =str(x)
# print(y)
# print(type(y))

# %%
#write a Python program that takes two integers as input: the number of apples in a basket and the number of people. The program should compute the following using arithmetic operators:

# The number of apples each person gets if they are divided equally.
# The number of apples left over after dividing them equally.
# The total apples needed to ensure that each person gets at least 5 apples.

# apple1 = int(input("number of apples in the basket "))
# people1 = int(input("number of people "))

# people2 = apple1//people1
# apple_left = apple1%people1
# total_apple_req= people1*5

# print(people2)
# print(apple_left)
# print(total_apple_req)


# Write a Python program that takes three integers as input and computes their average. Print the average.

# number1 = float(input("enter number one "))
# number2 = float(input("enter number two "))
# number3 = float(input("enter nunmber three "))

# average = (number1+number2+number3)/3
# print(average)


# Write a Python program to calculate the total salary for an employee. Given the base salary and the number of overtime hours worked, where overtime is paid at 1.5 times the base salary rate per hour.


# overtime_work = int(input("how many hours of work"))
# base_salary = int(input("what is the base salary "))
# hourly_rate = int(input("what is the hourly rate"))

# overtime_pay = hourly_rate*1.5*overtime_work

# total_salary =overtime_pay+base_salary

# print(total_salary)


Write a Python program that calculates the monthly salary of an employee based on the number of hours worked per week and the hourly wage. Assume there are 4 weeks in a month. Print the result


Write a Python program to calculate the simple interest. Given the principal amount, annual interest rate (in percentage), and time in years

#Write a Python program that calculates the monthly salary of an employee based on the number of hours worked per week and the hourly wage. Assume there are 4 weeks in a month. Print the result


# hours_per_week = float(input("Enter the number of hours worked per week: "))
# hourly_wage = float(input("Enter the hourly wage: "))

# monthly_salary = hours_per_week*hourly_wage*4

# print(monthly_salary)





#Write a Python program to calculate the simple interest. Given the principal amount, annual interest rate (in percentage), and time in years

# principal = float(input("Enter the principal amount: "))
# rate = float(input("Enter the annual interest rate in percentage: "))
# time = float(input("Enter the time in years: "))

# simple_interest = (principal * rate * time) / 100

# print(simple_interest)
