# %%
# Functions:A function is a block of code with only runs when it is called.
# You can pass data ,values.
# A function can return data as a result.
# uses:
# 1.code Reusability;
# function allows you to reuse code without rewriting it multiple code.
# 2 Avoid Redundancy:you avoid repeating the same block of code multiple times.
# 3.Debugging and testing: functions make it easier to test and debug specific part


def function():
#     print("hey how are u?")

# #function call
# function()


# def user(name):
#     print("Hello",name)
# user("Alice")

# def add_numbers(a,b):
#     print(a,b)
# add_numbers(1,2)


# def greet(name = "Guest"):
#     print(name)
# greet()
# greet("John")



def add_number(a,b):
#     return a+b
    
# result = add_number(3,4)
# print(result)


# def check_number(num):
#     if num>0:
#         print("This is positive")
#     elif num<0:
#         print("this is negative")
#     else:
#         print("Zero")
        
# check_number(5)
# check_number(-3)
# check_number(0)




# def print_numbers(n):
#     for i in range(1,n+1):
#         print(i)
# print_numbers(4)


# def check_even_odd(num):
#     if num%2 ==0:
#         print(num,"is even")
#     else:
#         print(num,"is odd")

# check_even_odd(10)
# check_even_odd(7)



# def add_two_numbers():
#     num1 = int(input("Enter the first number"))
#     num2 = int(input("Enter the second number"))
    
#     return num1+ num2
# result = add_two_numbers()
# print(result)


# def add_two_numbers():
#     num1 = in

# def add_two_numbers():
#     num1 = int(input("Enter the first number"))
#     num2 = int(input("Enter the second number"))
    
#     print(num1+num2)
    
# add_two_numbers()











    









    
# of the program.# def check_number():
#     for num in range (1,21):
#         if num % 2 == 0:
#             print(num,"is an even number")
#         else:
#             print(num,"is an odd number")
# check_number()

# def add_numbers():
#     num1= int(input("enter the first number: "))
#     num2= int(input("enter the second number: "))
    
#     return num1*num2
# result = add_numbers()
# print(result)




# def add_num(a,b):
#     return a+b
# result= add_num(2,1)
# print(result)

# def greet(name = "guests"):
#     print(name)
# greet()
# greet("vaibhav")


# Factorial:
# def factorial(n):
#     if n ==0 or n==1:
#         return 1
#     else:
#         return n *factorial(n-1)
# print(factorial(4))



# fibonaci series:
# def fibonaci_series(n):
#     a,b =0,1
#     for numbers in range (n):
#         print(a)
#         a,b = b,a+b
# fibonaci_series(10)
