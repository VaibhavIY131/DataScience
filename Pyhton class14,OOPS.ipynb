# %%
Oops:Modular, Scalable, maintainable.
priciple: classes, objects, inheritance,encapsulation,polymorphism, abstraction.
In python oops is a programming that uses objects, classes. it aims to implement
real-world entities like inheritance,encapsulation,polymorphism, abstraction.
The main concept of oops in python is to bind the data and function that work together
in single unit so that no other part can access the data.
python class:
A class is collection of objects. A class contains the blueprints or the prototype
from which the objects are being created.It is logical entity that contains
some attributes and methods.without self the class would not know which object's data to access. making it 
impossible to have unique data for each instance.


# OOPS:

# class book:
#     def __init__(self,title, author, year):
#         self.title = title
#         self.author = author
#         self.year = year
        
#     def book_info(self):
#         return self.title, self.author, self.year
        
# book1 = book("G.O.T", "Stark", 1999)
# book2 = book("falls", "Jon", 2001 )

# print(book1.book_info())
# print(book2.book_info())        


# class person:
#     def __init__(self,name,age):
#         self.name = name
#         self.age = age
        
#     def person_info(self):
#         print(self.name,self.age)

# person1 = person("BOB",25)
# person2 = person("Annie",22)

# person1.person_info()
# person2.person_info()


single inhertance 









    2.Multilevel Inheritance:
In multilvel inheritajce a class is derived from a parent class
which is a also derived from anothe class .
    
class GrandParent:
    
    
class Parent(GrandParent):
    
class child(Parent):


Parent class
class Vehical:
    def type(self):
        return "vehical"
        
class Car(Vehical):
    def wheels(self):
        return " wheels"


class electricCar(Car):
    def power(self):
        return "electric"

tesla = electricCar()

print(tesla.type())       
prin
print(tesla.type())       
print(tesla.wheels())      
print(tesla.power())      



Multiple inheritance:
In multiple inheritance,a child class inherits from more than one parent class.
class Parent1:
    
class Parent2:
    
    
class child(Parent1,Parent2)


class Engine:
    def engine_type(self):
        return "diesel"

class Body:
    def body_type(self):
        return "suv"
        
class brand(Engine,Body):
    def brand_type(self):
        return "Audi"
        
car = brand()
print(ccar = brand()
print(c
car = brand()
print(car.engine_type())
print(car.body_type())
print(car.brand_type())
You

# method overriding:

# class animal:
#     def sound(self):
#         return "animal sound"
        
# class Dog(animal):
#     def sound (self):
#         return "Bark"

# class Cat(animal):
#     def sound(self):
#         return "Meow"

# dog = Dog()
# cat = Cat()

# print(dog.sound())
# print(cat.sound())



# Duck Typing:


# class Car:
#     def start(self):
#         return "Car Engine"
        
# class Boat:
#     def start(self):
#         return "Boat Engine"

# def start_engine(vehicle):
#     print(vehicle.start())
    
    
# car = Car()
# boat = Boat()

# start_engine(car)
# start_engine(boat)



# compile time polymorphism



# class vector:
#     def __init__(self,x,y):
#         self.x = x
#         self.y = y
    
#     def __add__(self,other):
#         return vector(self.x+other.x,self.y+other.y)
        
# v1 = vector(2,3)
# v2 = vector(5,6)
# v3 = v1+v2

# print(v3.x+v3.y)
