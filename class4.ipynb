# %%
# 2.comparison operators:
# x = 5
# y = 10
# print(x==y)
# print(x!=y)
# print(x>y)
# print(x<y)
# print(x>=y)
# print(x<=y)

# 3.Logical operators:
# and:Return True if both statements are true.
# or:Returns True if one statement is true.

# not:Reverse the result.return false if true and if true than return false.

# x = True
# y = False
# print(x and y)
# print(x or y)
# print(not x)

# Assignment operators:
# x = 3
# x -=2
# print(x)

# Write a Python program to check if two numbers are equal, or one is greater than the other, and display the result.




# number_1 = float(input("enter the first number: "))
# number_2 = float(input("enter the second number: "))

# print(number_1 == number_2)
# print(number_1 > number_2)

# a= number_1 == number_2
# print(" both number are eaual", a)



# Write a Python program to check if both conditions (x > 10 and y < 5) are true using logical operators.


# x = float(input("enter the value of x: "))     



# y = float(input("enter the value of y: "))

# z = (x > 10 or y < 5)

# print(z)


# Demonstrate the use of assignment operators by incrementing, decrementing, multiplying, and dividing a variable.

# num_1 = float(input("enter the first number: "))

# num_1 +=5
# print(num_1)

# num_1 -=5
# print(num_1)

# num_1 *=5
# print(num_1)


Create a Python program to compare three numbers and print whether they are all equal, any two are equal, or all are different using only comparison operators.
